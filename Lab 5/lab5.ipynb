# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Survived"].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
new_df = df[df["Age"] < 10]
new_df["Survived"].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
df[["Sex", "Survived"]].groupby(["Sex"]).value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sex,Survived'>

# %%
df[["Pclass", "Survived"]].groupby(["Pclass"]).value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass,Survived'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Age.nunique()
# Out:
# 88

# %%
column_names = ["Survived", "Pclass", "Embarked", "SibSp"]

# %%
def showBar(col, group=None):
    if group is None:
        value = df[col]
        value_counts = value.value_counts()
        plt.title(col)
        plt.bar(value_counts.index, value_counts)
        plt.show()
    else:
        value = df[[col, group]]
        value_counts = value.groupby([group]).value_counts().plot.bar()
        plt.show()

#showBar("Survived", "Sex")
for columns in column_names:
    showBar(columns, "Sex")

# %%
fare = df["Fare"]
range = [0, 100, 200, 300, 400, 500]
#plt.hist(fare, bins=20, color="green", edgecolor="black")
plt.hist(fare, range, color="green", edgecolor="black")
# Out:
# (array([838.,  33.,  17.,   0.]),
#  array([  0, 100, 200, 300, 400]),
#  <BarContainer object of 4 artists>)

# %%
#correlation heatmap
newDf = df.drop(columns=["Name"])
correlation = newDf.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 3
#       1 #correlation heatmap
#       2 newDf = df.drop(columns=["Name"])
# ----> 3 correlation = newDf.corr()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
# ...

# %%
import seaborn as sns

sns.heatmap(df.corr())
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 3
#       1 import seaborn as sns
# ----> 3 sns.heatmap(df.corr())
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...
